# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 592

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = "https://api.openweathermap.org/data/2.5/weather?q=" 
units = "imperial"

citydata = []

i = 0

for city in cities:
    i = i + 1
    url = base_url + city + "&appid=" + weather_api_key + "&units=" + units
    try:
        response = requests.get(url).json()
        temperature= response["main"]["temp"]
        latitude = response["coord"]["lat"]
        longitude = response["coord"]["lon"]
        humidity = response["main"]["humidity"]
        wind_speed = response["wind"]["speed"]
        cloudiness = response["clouds"]["all"]
        country = response["sys"]["country"]
        date = response["dt"]
        citydata.append({"City": city,
                         "Country": country,
                         "Date": date,
                        "Temperature": temperature,
                        "Latitude": latitude,
                        "Longitude": longitude,
                        "Humidity": humidity,
                        "Wind Speed": wind_speed,
                        "Cloudiness": cloudiness,})
        
        print(f'City {i}|{city}')
        
        time.sleep(.08)
    
#If no city data is found, print 'No City Data Found' and create an exception to pass to the next city (i)
    
    except:
        print(f'No City Data Found')
        pass
# Out:
# City 1|tromso
# City 2|rikitea
# City 3|punta arenas
# City 4|qaanaaq
# City 5|humberto de campos
# City 6|merauke
# City 7|tuktoyaktuk
# No City Data Found
# City 9|coquimbo
# City 10|mataura
# City 11|georgetown
# City 12|husavik
# City 13|kapaa
# City 14|vaini
# No City Data Found
# City 16|kodiak
# City 17|busselton
# City 18|narsaq
# No City Data Found
# City 20|port lincoln
# City 21|sao joao da barra
# City 22|ugep
# City 23|bloemhof
# City 24|te anau
# City 25|hithadhoo
# City 26|saint-philippe
# City 27|teacapan
# City 28|neiafu
# City 29|san cristobal
# City 30|muyezerskiy
# City 31|dikson
# City 32|machico
# City 33|ushuaia
# No City Data Found
# City 35|san quintin
# City 36|bluff
# City 37|cape town
# City 38|ilulissat
# City 39|demirci
# City 40|lorengau
# No City Data Found
# City 42|tasiilaq
# City 43|athabasca
# City 44|santiago del estero
# City 45|pointe michel
# City 46|college
# City 47|mahebourg
# City 48|bacungan
# City 49|avarua
# City 50|jamestown
# City 51|nome
# City 52|tuatapere
# City 53|vila franca do campo
# City 54|port alfred
# City 55|gorontalo
# City 56|luancheng
# City 57|ulaangom
# City 58|mizdah
# City 59|kibala
# City 60|dali
# City 61|albany
# City 62|axim
# City 63|hambantota
# City 64|puerto ayacucho
# City 65|araouane
# City 66|voi
# City 67|asfi
# City 68|haines junction
# No City Data Found
# City 70|saldanha
# City 71|visby
# City 72|port hedland
# City 73|cidreira
# City 74|along
# City 75|pisco
# City 76|kaitangata
# City 77|monteagudo
# City 78|shimanovsk
# No City Data Found
# No City Data Found
# City 81|hermanus
# City 82|khatanga
# City 83|praia da vitoria
# City 84|geraldton
# City 85|pangnirtung
# City 86|dakar
# City 87|asau
# City 88|vallenar
# City 89|batyrevo
# City 90|hobart
# City 91|souillac
# City 92|bathsheba
# City 93|dondukovskaya
# City 94|vanino
# City 95|gambela
# City 96|provideniya
# City 97|port elizabeth
# City 98|sao filipe
# City 99|clearwater
# City 100|iqaluit
# City 101|klaksvik
# City 102|port hardy
# City 103|butzow
# City 104|juneau
# City 105|carnarvon
# City 106|melchor de mencos
# City 107|victoria
# City 108|bethel
# City 109|guerrero negro
# City 110|balikpapan
# City 111|puerto ayora
# City 112|mumford
# City 113|valparaiso
# No City Data Found
# City 115|kruisfontein
# City 116|atuona
# City 117|pevek
# City 118|isangel
# City 119|san antonio
# City 120|divo
# City 121|la cruz
# City 122|tierranueva
# City 123|adrar
# City 124|henties bay
# City 125|senanga
# No City Data Found
# City 127|beringovskiy
# City 128|avera
# City 129|sorland
# City 130|huejuquilla el alto
# City 131|hilo
# City 132|roma
# City 133|forte dei marmi
# City 134|remanso
# City 135|mehamn
# City 136|maracas
# City 137|ribeira grande
# City 138|new norfolk
# City 139|partenit
# City 140|rundu
# City 141|ust-tsilma
# No City Data Found
# No City Data Found
# City 144|marmaris
# City 145|aklavik
# City 146|hasaki
# No City Data Found
# City 148|argir
# City 149|upernavik
# City 150|hami
# City 151|vao
# City 152|lebu
# City 153|east london
# City 154|butaritari
# City 155|prnjavor
# City 156|imbituba
# City 157|komsomolskiy
# City 158|tanout
# City 159|thompson
# City 160|saint-louis
# City 161|san giovanni rotondo
# City 162|eirunepe
# City 163|puerto lempira
# City 164|los llanos de aridane
# City 165|constitucion
# City 166|longyearbyen
# City 167|cabo san lucas
# City 168|arraial do cabo
# City 169|gravdal
# City 170|bandar-e lengeh
# City 171|salalah
# City 172|maceio
# City 173|rorvik
# No City Data Found
# City 175|neuquen
# City 176|rio grande
# City 177|vostok
# No City Data Found
# City 179|buala
# City 180|riyadh
# City 181|fallingbostel
# City 182|yellowknife
# City 183|baruun-urt
# City 184|hondo
# City 185|pahrump
# City 186|jacqueville
# City 187|moen
# City 188|ponta do sol
# City 189|caldwell
# City 190|amuntai
# City 191|hamilton
# City 192|greenville
# City 193|kathmandu
# City 194|bredasdorp
# City 195|luderitz
# City 196|saskylakh
# City 197|mar del plata
# City 198|faanui
# City 199|leningradskiy
# No City Data Found
# City 201|eqbaliyeh
# City 202|vardo
# City 203|fortuna
# No City Data Found
# City 205|marion
# City 206|san patricio
# City 207|ewa beach
# No City Data Found
# City 209|castro
# City 210|galle
# City 211|bouna
# City 212|trincomalee
# City 213|miri
# City 214|nelson bay
# No City Data Found
# City 216|bira
# City 217|rapid valley
# City 218|kupang
# City 219|dunmore east
# City 220|comodoro rivadavia
# City 221|chicama
# No City Data Found
# City 223|antofagasta
# City 224|mount gambier
# City 225|belyy yar
# City 226|mani
# City 227|natal
# No City Data Found
# City 229|kieta
# City 230|chubbuck
# City 231|birao
# No City Data Found
# City 233|carmarthen
# City 234|olafsvik
# City 235|sobolevo
# City 236|tabuk
# City 237|los algarrobos
# City 238|port hueneme
# City 239|mwinilunga
# City 240|coihaique
# City 241|egvekinot
# City 242|filingue
# City 243|pedernales
# City 244|qandala
# City 245|baykit
# City 246|eidfjord
# City 247|tiksi
# City 248|ponta delgada
# City 249|mabaruma
# City 250|derzhavinsk
# City 251|sompeta
# City 252|varjota
# City 253|porto santo
# No City Data Found
# City 255|conceicao da barra
# City 256|micheweni
# City 257|half moon bay
# City 258|kushiro
# City 259|dingle
# City 260|tete
# City 261|cayenne
# City 262|kaoma
# No City Data Found
# City 264|basco
# City 265|mamakan
# City 266|chokurdakh
# City 267|formosa
# City 268|srednekolymsk
# City 269|santa maria
# City 270|tuy hoa
# City 271|hofn
# City 272|bonavista
# City 273|lata
# City 274|kudahuvadhoo
# City 275|el tigre
# No City Data Found
# City 277|marsh harbour
# City 278|margate
# No City Data Found
# City 280|koygorodok
# City 281|kidal
# City 282|powell
# City 283|bud
# City 284|serenje
# City 285|paysandu
# City 286|evensk
# City 287|burnie
# City 288|balkhash
# No City Data Found
# City 290|zhigansk
# City 291|esperance
# City 292|airai
# City 293|awassa
# City 294|waddan
# City 295|bambous virieux
# City 296|arona
# City 297|clyde river
# City 298|lagoa
# City 299|grindavik
# City 300|umm lajj
# City 301|damietta
# City 302|caarapo
# City 303|tairua
# City 304|warmbad
# City 305|wilmington
# City 306|blejoi
# City 307|ponte nova
# City 308|bereda
# City 309|torbay
# City 310|severo-kurilsk
# City 311|ulladulla
# City 312|puerto cabezas
# City 313|monywa
# City 314|lexington
# City 315|benavente
# City 316|westport
# No City Data Found
# City 318|urumqi
# No City Data Found
# City 320|pringsewu
# City 321|fairfield
# City 322|gizo
# City 323|antalaha
# City 324|jacobina
# City 325|sedalia
# City 326|porgera
# City 327|bengkulu
# City 328|zaozerne
# City 329|saint-denis
# City 330|seoul
# City 331|puerto leguizamo
# City 332|zheshart
# City 333|shelburne
# City 334|soligalich
# City 335|brooks
# City 336|yar-sale
# City 337|akyab
# City 338|cherskiy
# No City Data Found
# City 340|laje
# City 341|scottsbluff
# City 342|bagula
# City 343|isparta
# City 344|maniitsoq
# City 345|kirakira
# City 346|norman wells
# City 347|acapulco
# City 348|erenhot
# City 349|kalabo
# City 350|alice springs
# City 351|nichinan
# City 352|ubinskoye
# City 353|xihe
# City 354|fare
# City 355|lethem
# City 356|barrow
# City 357|dinguiraye
# City 358|nikolskoye
# City 359|mayna
# City 360|port macquarie
# City 361|naze
# No City Data Found
# City 363|pec
# City 364|peniche
# City 365|taiobeiras
# City 366|masyaf
# City 367|vanimo
# City 368|goksun
# City 369|kenai
# City 370|nyurba
# City 371|padang
# City 372|kostomuksha
# City 373|sambava
# City 374|penzance
# City 375|faranah
# City 376|paraiso
# City 377|konstantinovka
# City 378|sur
# City 379|liwale
# City 380|matamoros
# City 381|karratha
# City 382|shimoda
# City 383|grand gaube
# City 384|north bend
# City 385|necochea
# City 386|lasa
# City 387|gladstone
# City 388|kyakhta
# City 389|ancud
# City 390|phan thiet
# City 391|mareeba
# City 392|broome
# City 393|torbat-e jam
# City 394|arlit
# City 395|leh
# City 396|ostersund
# City 397|ladario
# City 398|kyzyl-suu
# City 399|pandan
# No City Data Found
# City 401|nantucket
# City 402|havre
# City 403|sola
# City 404|mount isa
# City 405|san carlos del zulia
# City 406|lihula
# City 407|tambura
# City 408|berlevag
# No City Data Found
# City 410|tessalit
# City 411|mocuba
# No City Data Found
# City 413|minyar
# City 414|aden
# City 415|yulara
# City 416|teknaf
# City 417|nachalovo
# City 418|gavrilovka vtoraya
# City 419|am timan
# City 420|cabedelo
# City 421|mariental
# City 422|santa rita
# City 423|biltine
# City 424|great yarmouth
# City 425|wenling
# City 426|yeppoon
# City 427|hailun
# City 428|gazanjyk
# City 429|mazamari
# City 430|chapais
# City 431|marsabit
# City 432|port keats
# City 433|hobyo
# City 434|kahului
# City 435|wamba
# City 436|ta khmau
# City 437|ahipara
# City 438|staroutkinsk
# City 439|bardiyah
# City 440|dunkirk
# City 441|yuncheng
# City 442|el alto
# City 443|mersing
# City 444|nemuro
# City 445|san pedro
# City 446|loukhi
# City 447|cacoal
# City 448|graulhet
# City 449|ahuimanu
# City 450|bilibino
# City 451|kashan
# City 452|kazerun
# City 453|raudeberg
# City 454|biak
# City 455|asosa
# City 456|dubovskoye
# City 457|auki
# City 458|dulce nombre de culmi
# City 459|catio
# City 460|magnolia
# City 461|bandarbeyla
# City 462|pitimbu
# City 463|akhmim
# City 464|mitsamiouli
# City 465|san luis
# City 466|ambilobe
# City 467|gat
# City 468|chakrata
# City 469|sebeta
# City 470|yemelyanovo
# City 471|dunedin
# City 472|daru
# City 473|dhanwar
# City 474|honningsvag
# City 475|black river
# City 476|gordeyevka
# City 477|rovinj
# City 478|chuy
# City 479|merthyr tydfil
# No City Data Found
# City 481|paciran
# City 482|chhindwara
# City 483|youkounkoun
# City 484|atasu
# City 485|nanortalik
# City 486|piet retief
# City 487|samarai
# City 488|boyolangu
# City 489|kavieng
# City 490|richards bay
# No City Data Found
# No City Data Found
# City 493|kolomak
# City 494|kultuk
# City 495|puri
# No City Data Found
# City 497|xai-xai
# City 498|lompoc
# No City Data Found
# City 500|marysville
# City 501|krasnoselkup
# City 502|la ronge
# City 503|san jose
# City 504|russell
# City 505|amalapuram
# City 506|talnakh
# City 507|puerto escondido
# City 508|touros
# City 509|belz
# City 510|port blair
# City 511|bela
# City 512|kavaratti
# City 513|farmington
# City 514|portland
# City 515|magaria
# City 516|paamiut
# City 517|skhisma
# City 518|kawalu
# City 519|luangwa
# City 520|naples
# City 521|tiznit
# City 522|orocue
# City 523|dennery
# City 524|kamina
# No City Data Found
# City 526|ratesti
# City 527|nuevo progreso
# City 528|kurara
# City 529|isla vista
# City 530|bhimunipatnam
# City 531|harper
# No City Data Found
# No City Data Found
# City 534|garachine
# City 535|bastia
# City 536|weymouth
# No City Data Found
# City 538|mainaguri
# No City Data Found
# City 540|rawson
# City 541|tezpur
# City 542|taoudenni
# City 543|ostrovnoy
# City 544|fukue
# City 545|itamaraca
# City 546|stephenville
# No City Data Found
# City 548|mundi
# City 549|cockburn town
# City 550|kapoeta
# City 551|huarmey
# City 552|kununurra
# City 553|galveston
# City 554|thinadhoo
# City 555|quelimane
# City 556|saint george
# City 557|havelock
# City 558|nhamunda
# City 559|mana
# City 560|port pirie
# City 561|voh
# City 562|maragogi
# City 563|kubinka
# City 564|greencastle
# City 565|bluefield
# No City Data Found
# City 567|walvis bay
# City 568|alenquer
# City 569|yerbogachen
# City 570|gilgit
# City 571|berdigestyakh
# City 572|da nang
# City 573|sisimiut
# City 574|kiunga
# City 575|tahta
# City 576|acarau
# City 577|kaputa
# City 578|benghazi
# City 579|faya
# City 580|labuan
# No City Data Found
# City 582|kyabe
# City 583|noumea
# City 584|sangmelima
# City 585|chumikan
# City 586|anadyr
# City 587|shiloh
# City 588|altamirano
# City 589|manokwari
# City 590|williams lake
# City 591|tezu
# City 592|pereira barreto

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
citydata_df = pd.DataFrame(citydata)
citydata_df
# Out:
#                    City Country        Date  Temperature  Latitude  Longitude  \
# 0                tromso      NO  1588050721        30.20     69.65      18.96
# 1               rikitea      PF  1588050801        78.04    -23.12    -134.97
# 2          punta arenas      CL  1588050828        28.40    -53.15     -70.92
# 3               qaanaaq      GL  1588050797        15.84     77.48     -69.36
# 4    humberto de campos      BR  1588050883        75.31     -2.60     -43.46
# ..                  ...     ...         ...          ...       ...        ...
# 540          altamirano      MX  1588051161        58.30     16.88     -92.15
# 541           manokwari      ID  1588051162        82.63     -0.87     134.08
# 542       williams lake      CA  1588050991        41.00     52.14    -122.14
# 543                tezu      IN  1588051162        89.65     27.92      96.17
# 544     pereira barreto      BR  1588051163        66.70    -20.64     -51.11
#
#      Humidity  Wind Speed  Cloudiness
# 0          63        8.05          40
# 1          79       14.34          10
# 2         100        4.70           0
# 3          91        5.53         100
# 4          92        2.82         100
# ..        ...         ...         ...
# 540        49        1.19          14
# 541        81       14.09          96
# 542        51        6.93          75
# 543        31        4.81          98
# 544        74        8.59           3
#
# [545 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
