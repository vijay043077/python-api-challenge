# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = "https://api.openweathermap.org/data/2.5/weather?q=" 
units = "imperial"

citydata = []

i = 0

for city in cities:
    i = i + 1
    url = base_url + city + "&appid=" + weather_api_key + "&units=" + units
    try:
        response = requests.get(url).json()
        temperature= response["main"]["temp"]
        latitude = response["coord"]["lat"]
        longitude = response["coord"]["lon"]
        humidity = response["main"]["humidity"]
        wind_speed = response["wind"]["speed"]
        cloudiness = response["clouds"]["all"]
        country = response["sys"]["country"]
        date = response["dt"]
        citydata.append({"City": city,
                         "Country": country,
                         "Date": date,
                        "Temperature": temperature,
                        "Latitude": latitude,
                        "Longitude": longitude,
                        "Humidity": humidity,
                        "Wind Speed": wind_speed,
                        "Cloudiness": cloudiness,})
        
        print(f'City {i}|{city}')
        
        time.sleep(.08)
    
#If no city data is found, print 'No City Data Found' and create an exception to pass to the next city (i)
    
    except:
        print(f'No City Data Found')
        pass
# Out:
# City 1|kavieng
# City 2|mataura
# City 3|kaka
# City 4|kuytun
# City 5|bluff
# City 6|hilo
# City 7|guerrero negro
# City 8|hobart
# City 9|zhigansk
# City 10|mayskiy
# City 11|ostrovnoy
# No City Data Found
# City 13|mar del plata
# City 14|rikitea
# City 15|ushuaia
# No City Data Found
# City 17|victoria
# City 18|sorong
# City 19|porto santo
# City 20|qaanaaq
# City 21|new norfolk
# City 22|tuktoyaktuk
# City 23|rio grande
# City 24|okhotsk
# City 25|namibe
# City 26|busselton
# City 27|codrington
# City 28|ous
# City 29|tuatapere
# City 30|jamestown
# City 31|xining
# City 32|port elizabeth
# City 33|vaini
# City 34|chernyshevskiy
# City 35|warmbad
# City 36|chokurdakh
# City 37|east london
# City 38|port macquarie
# City 39|bambous virieux
# City 40|albany
# City 41|broken hill
# No City Data Found
# City 43|port alfred
# City 44|port-gentil
# City 45|entre rios
# City 46|butaritari
# City 47|nikolskoye
# City 48|hermanus
# City 49|katherine
# City 50|tecpan
# City 51|najran
# City 52|kalmunai
# City 53|asau
# City 54|san jose
# No City Data Found
# City 56|rafraf
# City 57|severnyy
# City 58|punta arenas
# City 59|barao de melgaco
# No City Data Found
# No City Data Found
# City 62|lompoc
# City 63|numan
# City 64|belaya gora
# City 65|carnarvon
# City 66|castro
# No City Data Found
# City 68|ostersund
# City 69|puerto ayora
# City 70|ahipara
# City 71|faya
# City 72|chuy
# City 73|kulhudhuffushi
# City 74|aklavik
# No City Data Found
# No City Data Found
# City 77|kiama
# City 78|presque isle
# City 79|cabo san lucas
# City 80|atuona
# City 81|te anau
# City 82|cherskiy
# City 83|aksarka
# City 84|erzin
# City 85|fortuna
# City 86|thompson
# City 87|cape town
# City 88|sale
# City 89|kodiak
# No City Data Found
# City 91|bilibino
# City 92|lampa
# City 93|nong han
# City 94|trinidad
# City 95|buchanan
# City 96|hambantota
# City 97|tartagal
# No City Data Found
# City 99|alofi
# City 100|mitsamiouli
# City 101|torbay
# City 102|kapaa
# City 103|quang ngai
# City 104|barrow
# City 105|sept-iles
# City 106|upernavik
# City 107|ilulissat
# City 108|longyearbyen
# City 109|tasiilaq
# City 110|lorengau
# City 111|tateyama
# City 112|sao felix do xingu
# City 113|talnakh
# City 114|esperance
# City 115|saint-pierre
# No City Data Found
# City 117|bosaso
# City 118|saskylakh
# City 119|nome
# City 120|labuhan
# City 121|zheleznodorozhnyy
# City 122|mosetse
# City 123|port hardy
# City 124|sao joao do piaui
# No City Data Found
# City 126|arraial do cabo
# City 127|yining
# City 128|nueva florida
# City 129|chikhli
# City 130|oranjemund
# City 131|makakilo city
# City 132|vostok
# City 133|santa rosa
# City 134|mount gambier
# City 135|ribeira grande
# City 136|bredasdorp
# City 137|smithers
# City 138|touros
# City 139|tura
# No City Data Found
# No City Data Found
# City 142|norman wells
# City 143|iraquara
# City 144|balkhash
# No City Data Found
# City 146|hashtrud
# City 147|pevek
# City 148|louisville
# City 149|chernyshkovskiy
# City 150|shwebo
# City 151|kaitangata
# City 152|kontagora
# City 153|itarema
# City 154|avarua
# City 155|yumbe
# City 156|westport
# City 157|yar-sale
# City 158|tautira
# City 159|ajdabiya
# City 160|akyab
# City 161|massakory
# City 162|portland
# City 163|okakarara
# City 164|iranshahr
# City 165|hithadhoo
# No City Data Found
# City 167|catamarca
# City 168|fairbanks
# City 169|egvekinot
# City 170|anadyr
# City 171|tambacounda
# City 172|los llanos de aridane
# City 173|brae
# City 174|saint-philippe
# City 175|ancud
# City 176|nyrob
# City 177|abnub
# City 178|san cristobal
# City 179|vila franca do campo
# City 180|caravelas
# City 181|parana
# City 182|topolobampo
# City 183|hofn
# City 184|mahibadhoo
# No City Data Found
# City 186|perth
# City 187|saint george
# City 188|tiszanana
# City 189|tessalit
# City 190|half moon bay
# City 191|college
# City 192|san patricio
# City 193|airai
# City 194|salalah
# City 195|prince george
# City 196|amapa
# City 197|wagar
# City 198|aitape
# City 199|cururupu
# City 200|cuenca
# City 201|khatanga
# City 202|mahebourg
# City 203|bathsheba
# City 204|constantine
# City 205|coihaique
# City 206|basco
# City 207|bethel
# City 208|tilichiki
# City 209|manitouwadge
# City 210|kangaatsiaq
# City 211|mae sai
# City 212|yinchuan
# City 213|valdivia
# City 214|along
# City 215|kamaishi
# City 216|klaksvik
# City 217|fort nelson
# City 218|guarapuava
# City 219|ponta do sol
# City 220|acajutla
# City 221|asosa
# City 222|yulara
# City 223|muros
# City 224|puerto escondido
# City 225|pravokubanskiy
# City 226|puerto quijarro
# City 227|nanpiao
# City 228|voh
# City 229|georgetown
# City 230|stepnogorsk
# City 231|nerchinskiy zavod
# City 232|blagoyevo
# City 233|adrar
# City 234|cayenne
# City 235|alassio
# City 236|rawson
# No City Data Found
# City 238|kitui
# City 239|bongor
# City 240|sete
# City 241|olafsvik
# City 242|broome
# City 243|alpena
# City 244|roald
# City 245|qaqortoq
# City 246|souillac
# City 247|quatre cocos
# City 248|surt
# City 249|kamenka
# No City Data Found
# City 251|rorvik
# City 252|la peca
# No City Data Found
# No City Data Found
# City 255|tiksi
# City 256|druzhba
# City 257|athabasca
# City 258|grindavik
# City 259|lata
# City 260|pemangkat
# City 261|the valley
# City 262|shingu
# City 263|mamou
# City 264|kozhva
# No City Data Found
# City 266|simao
# City 267|bastia
# No City Data Found
# City 269|nurota
# City 270|pangoa
# City 271|monaco-ville
# City 272|lahaina
# City 273|bara
# City 274|dingle
# City 275|hirara
# City 276|provideniya
# City 277|salamiyah
# No City Data Found
# City 279|lebu
# City 280|san andres
# City 281|dunedin
# City 282|dhidhdhoo
# No City Data Found
# City 284|clonakilty
# City 285|contramaestre
# City 286|malpe
# No City Data Found
# City 288|yellowknife
# City 289|necochea
# City 290|isangel
# City 291|puerto ayacucho
# No City Data Found
# City 293|kavaratti
# City 294|savannah bight
# City 295|amfiklia
# City 296|leshukonskoye
# City 297|waddan
# City 298|mokhsogollokh
# City 299|meulaboh
# City 300|cidreira
# City 301|presidencia roque saenz pena
# City 302|comodoro rivadavia
# No City Data Found
# City 304|uglich
# City 305|kpalime
# City 306|stawell
# City 307|pemberton
# City 308|waingapu
# City 309|seydi
# City 310|kushmurun
# City 311|port moresby
# City 312|port blair
# City 313|shelburne
# City 314|destin
# City 315|oistins
# City 316|arco
# City 317|mayo
# No City Data Found
# City 319|ambon
# City 320|sisimiut
# City 321|rosarito
# City 322|jalu
# No City Data Found
# City 324|karibib
# City 325|xinzhou
# City 326|spas-klepiki
# City 327|carutapera
# City 328|constitucion
# City 329|queanbeyan
# No City Data Found
# City 331|kokopo
# City 332|iqaluit
# City 333|la roche-sur-yon
# City 334|husavik
# City 335|neepawa
# City 336|luderitz
# City 337|hasaki
# City 338|carballo
# City 339|mbulu
# City 340|hamilton
# No City Data Found
# City 342|naze
# City 343|gravdal
# City 344|banda aceh
# City 345|nanortalik
# City 346|pandan
# City 347|new kensington
# City 348|kenai
# City 349|mwense
# City 350|arlit
# City 351|alta floresta
# City 352|pisco
# City 353|bubaque
# City 354|tromso
# City 355|dikson
# City 356|igunga
# No City Data Found
# City 358|magadan
# City 359|flin flon
# City 360|mecca
# City 361|san policarpo
# City 362|bengkulu
# City 363|harrai
# City 364|saint-augustin
# City 365|vanimo
# City 366|imeni poliny osipenko
# City 367|namikupa
# City 368|severo-kurilsk
# City 369|gold coast
# City 370|alenquer
# City 371|aksarayskiy
# City 372|hun
# City 373|peterhead
# City 374|bogorodskoye
# City 375|walldurn
# City 376|praia da vitoria
# City 377|zhovtneve
# City 378|yerbogachen
# City 379|jingdezhen
# City 380|terrace bay
# City 381|mumford
# City 382|ramhormoz
# City 383|pacific grove
# City 384|matagami
# City 385|phultala
# City 386|caruray
# City 387|balkany
# City 388|saldanha
# City 389|segezha
# City 390|prokuplje
# City 391|coquimbo
# City 392|plettenberg bay
# No City Data Found
# City 394|awjilah
# City 395|albert lea
# City 396|sitka
# City 397|montrose
# City 398|pangnirtung
# No City Data Found
# City 400|marquette
# City 401|jijiga
# City 402|aketi
# City 403|yumen
# City 404|northam
# City 405|nishihara
# City 406|tanout
# City 407|petropavlovsk-kamchatskiy
# City 408|nang rong
# City 409|ivanteyevka
# No City Data Found
# City 411|byron bay
# City 412|san rafael
# City 413|moerai
# City 414|sao filipe
# City 415|lodhran
# City 416|marawi
# City 417|vilyuysk
# City 418|katsuura
# City 419|springbok
# City 420|soyo
# City 421|sovetskiy
# City 422|atambua
# No City Data Found
# City 424|japura
# City 425|kununurra
# City 426|jiexiu
# City 427|rantauprapat
# City 428|denpasar
# City 429|nemuro
# City 430|darlawn
# City 431|bonthe
# City 432|humaita
# City 433|sukhumi
# City 434|andra
# City 435|hobyo
# City 436|nenjiang
# City 437|tigzirt
# City 438|coahuayana
# City 439|rock sound
# City 440|irece
# City 441|rosetta
# City 442|santo antonio do ica
# City 443|mersing
# City 444|price
# City 445|glyadyanskoye
# City 446|el alto
# City 447|khilok
# City 448|raichur
# City 449|tomatlan
# City 450|maldonado
# City 451|tancanhuitz
# City 452|komsomolskiy
# City 453|tetiyiv
# No City Data Found
# City 455|vila velha
# City 456|nordfjordeid
# City 457|badiraguato
# City 458|nelidovo
# City 459|koulamoutou
# City 460|mount vernon
# City 461|porto novo
# City 462|manbij
# City 463|whitefish
# City 464|choix
# City 465|maun
# City 466|thinadhoo
# City 467|mindelo
# City 468|anito
# City 469|poum
# City 470|katwijk
# City 471|mount isa
# City 472|sawtell
# City 473|nara
# City 474|padang
# City 475|gayeri
# No City Data Found
# City 477|havelock
# City 478|aljezur
# City 479|yanam
# City 480|juneau
# City 481|bonavista
# City 482|russell
# City 483|qasigiannguit
# City 484|richards bay
# City 485|pangody
# City 486|piacenza
# City 487|kruisfontein
# City 488|moose factory
# City 489|santa paula
# No City Data Found
# City 491|beloha
# City 492|tolaga bay
# City 493|kahului
# City 494|nichinan
# No City Data Found
# No City Data Found
# City 497|whitianga
# City 498|innisfail
# City 499|norsup
# City 500|bani walid
# City 501|dukat
# City 502|kaberamaido
# City 503|camacha
# City 504|leningradskiy
# City 505|salinopolis
# City 506|liwale
# City 507|aykhal
# City 508|maningrida
# City 509|assare
# City 510|erenhot
# City 511|kvitok
# City 512|manta
# City 513|marzuq
# City 514|pangai
# City 515|rosehearty
# City 516|vysotskoye
# City 517|goundam
# City 518|terrace
# City 519|pendleton
# City 520|takoradi
# City 521|wajir
# City 522|marsa matruh
# City 523|mehamn
# City 524|puro
# City 525|berlevag
# No City Data Found
# City 527|san francisco
# City 528|bonfim
# City 529|khanpur
# No City Data Found
# City 531|eureka
# City 532|calvinia
# City 533|sorland
# City 534|grand gaube
# City 535|beringovskiy
# City 536|cerrito
# City 537|malkangiri
# City 538|rudnichnyy
# City 539|skegness
# City 540|beni suef
# City 541|narsaq
# City 542|smirnykh
# City 543|samarai
# City 544|manggar
# City 545|lazaro cardenas
# No City Data Found
# City 547|tiznit
# City 548|santa maria
# City 549|nizhniy baskunchak
# City 550|vire
# City 551|pacifica
# City 552|batagay-alyta
# City 553|vardo
# City 554|kargil
# City 555|solok
# City 556|port hawkesbury
# City 557|roma
# No City Data Found
# City 559|ihosy
# City 560|jacqueville
# City 561|jimalalud
# City 562|almeirim
# City 563|sao geraldo do araguaia
# City 564|hualmay
# City 565|fare
# City 566|valea calugareasca
# City 567|marigot
# City 568|yongan
# City 569|kommunisticheskiy
# City 570|san quintin
# City 571|chor
# City 572|yantikovo
# City 573|barbosa ferraz
# City 574|tarakan
# City 575|washington
# City 576|baiao
# City 577|saint-joseph
# City 578|guane
# City 579|gari
# No City Data Found
# City 581|xam nua
# City 582|ballina
# City 583|lokosovo
# City 584|haines junction
# City 585|lagoa
# City 586|ulladulla
# No City Data Found
# City 588|aleksandrov gay
# City 589|ladario
# City 590|klyuchi
# City 591|gweta
# City 592|evensk
# No City Data Found
# City 594|sibu
# City 595|deputatskiy
# City 596|oussouye
# City 597|sinnamary
# City 598|kasongo-lunda
# City 599|vanino
# City 600|kalabo
# City 601|dragor
# City 602|ngunguru
# City 603|santa fe
# City 604|avera
# City 605|mae hong son
# City 606|gat
# City 607|ati

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
citydata_df = pd.DataFrame(citydata)
citydata_df.head()
# Out:
#       City Country        Date  Temperature  Latitude  Longitude  Humidity  \
# 0  kavieng      PG  1588574147        84.34     -2.57     150.80        79
# 1  mataura      NZ  1588574147        41.41    -46.19     168.86        90
# 2     kaka      TM  1588574148        79.83     37.35      59.61        32
# 3   kuytun      RU  1588574148        63.63     54.34     101.50        31
# 4    bluff      NZ  1588574148        48.65    -46.60     168.33        75
#
#    Wind Speed  Cloudiness
# 0       10.54          82
# 1        3.85          76
# 2       10.92           0
# 3       13.98          82
# 4       14.92          71

# %%
citydata_df.to_csv('citydata.csv')

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(citydata_df["Latitude"], citydata_df["Temperature"], marker="o", facecolors="brown", edgecolors="red")

plt.title("City Latitude vs Temperature (April 2020)")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Latitude_vs_Temperature.png", dpi= 150)
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(citydata_df["Latitude"], citydata_df["Humidity"], marker = "o", facecolors='brown', edgecolors = 'orange')

plt.title("City Latitude vs Humidity (April 2020)")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Latitude_vs_Humidity.png", dpi= 150)
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(citydata_df["Latitude"], citydata_df["Cloudiness"], marker = "o", facecolors='brown', edgecolors = 'blue')

plt.title("City Latitude vs Cloudiness (April 2020)")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Latitude_vs_Cloudiness.png", dpi= 150)
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(citydata_df["Latitude"], citydata_df["Wind Speed"], marker = "o", facecolors='brown', edgecolors = 'green')

plt.title("City Latitude vs Wind Speed (April 2020)")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

plt.savefig("Latitude_vs_WindSpeed.png", dpi= 150)
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
# use Banking Desert activity
Northern = citydata_df.loc[citydata_df["Latitude"]>0]
Southern = citydata_df.loc[citydata_df["Latitude"]<0]

# %%
Northern.head()
# Out:
#              City Country        Date  Temperature  Latitude  Longitude  \
# 2            kaka      TM  1588574148        79.83     37.35      59.61
# 3          kuytun      RU  1588574148        63.63     54.34     101.50
# 5            hilo      US  1588573860        73.60     19.73    -155.09
# 6  guerrero negro      MX  1588574149        62.64     27.98    -114.06
# 8        zhigansk      RU  1588574150        33.12     66.77     123.37
#
#    Humidity  Wind Speed  Cloudiness
# 2        32       10.92           0
# 3        31       13.98          82
# 5        69        8.05          90
# 6        87       16.28          16
# 8        90        5.19           0

# %%
Southern.head()
# Out:
#              City Country        Date  Temperature  Latitude  Longitude  \
# 0         kavieng      PG  1588574147        84.34     -2.57     150.80
# 1         mataura      NZ  1588574147        41.41    -46.19     168.86
# 4           bluff      NZ  1588574148        48.65    -46.60     168.33
# 7          hobart      AU  1588574074        57.61    -42.88     147.33
# 11  mar del plata      AR  1588574152        56.61    -38.00     -57.56
#
#     Humidity  Wind Speed  Cloudiness
# 0         79       10.54          82
# 1         90        3.85          76
# 4         75       14.92          71
# 7         71       11.41          40
# 11       100       10.29         100

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = Northern["Latitude"]
y_values = Northern["Temperature"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = 'y=' + str(round(slope,2)) + 'x +' + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(6,10), fontsize = 12, color ='red')
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.title('Northern Hemisphere Max Temp vs Latitude')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = Southern["Latitude"]
y_values = Southern["Temperature"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = 'y=' + str(round(slope,2)) + 'x +' + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(-20,55), fontsize = 12, color ='red')
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.title('Southern Hemisphere Max Temp vs Latitude')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = Northern["Latitude"]
y_values = Northern["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = 'y=' + str(round(slope,2)) + 'x +' + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(55,20), fontsize = 12, color ='red')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Northern Hemisphere Humidity(%) vs Latitude')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = Southern["Latitude"]
y_values = Southern["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = 'y=' + str(round(slope,2)) + 'x +' + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(-40,40), fontsize = 12, color ='red')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title('Southern Hemisphere Humidity(%) vs Latitude')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = Northern["Latitude"]
y_values = Northern["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = 'y=' + str(round(slope,2)) + 'x +' + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(35,58), fontsize = 12, color ='red')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Northern Hemisphere Cloudiness(%) vs Latitude')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = Southern["Latitude"]
y_values = Southern["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = 'y=' + str(round(slope,2)) + 'x +' + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(-30,60), fontsize = 12, color ='red')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title('Southern Hemisphere Cloudiness(%) vs Latitude')
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = Northern["Latitude"]
y_values = Northern["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = 'y=' + str(round(slope,2)) + 'x +' + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(10,25), fontsize = 12, color ='red')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Northern Hemisphere Wind Speed(mph) vs Latitude')
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = Southern["Latitude"]
y_values = Southern["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values,y_values)
regress_values = x_values * slope + intercept
line_eq = 'y=' + str(round(slope,2)) + 'x +' + str(round(intercept,2))
plt.scatter(x_values, y_values)
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(-50,20), fontsize = 12, color ='red')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.title('Southern Hemisphere Wind Speed(mph) vs Latitude')
plt.show()

# %%
# New results given due to new API calls
